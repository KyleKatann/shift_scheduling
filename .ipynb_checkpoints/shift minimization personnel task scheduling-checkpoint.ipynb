# %%
import glob
import plotly.figure_factory as ff
import plotly.offline as pof
import datetime
import random
import networkx as nx

# %%
#スケジューリングするまえのjob
def drawrawwork(jobs):
    dt1 = datetime.datetime.now()
    pof.init_notebook_mode(connected=False)
    df = []
    c=0
    for s,e in jobs:
        df.append( dict(Task=c, Start=dt1 + datetime.timedelta(minutes=s), Finish=dt1 + datetime.timedelta(minutes=e), Resource='job') )
        c+=1

    colors = dict(job = 'rgb(198, 47, 105)')


    fig = ff.create_gantt(df, colors=colors, index_col='Resource', title='job Schedule',
                          show_colorbar=True, bar_width=0.1, showgrid_x=True, showgrid_y=True)

    # Jupyter Notebookで表示する場合
    pof.iplot(fig, filename='gantt-hours-minutes')

# %%
#スケジューリングした後のjob
def draw(jobs,dworkerwork):
    dt1 = datetime.datetime.now()
    pof.init_notebook_mode(connected=False)
    df = []
    
    
    for wk,w in dworkerwork.items():
        for wnumber in w:
            num=int(wnumber.replace("作業",""))
            df.append(
                dict(Task=wk, 
                     Start=dt1 + datetime.timedelta(minutes=jobs[num][0]), 
                     Finish=dt1 + datetime.timedelta(minutes=jobs[num][1]),
                     Resource=wk
                    )
            )
    colors = {worker :"rgb("+str(random.randint(100,255))+","+str(random.randint(100,255))+","+str(random.randint(100,255))+")" for worker in dworkerwork.keys()}
    


    fig = ff.create_gantt(df, 
                          colors=colors, 
                          index_col='Resource',
                          title='job Schedule',
                          show_colorbar=True, 
                          bar_width=0.1, 
                          showgrid_x=True, 
                          showgrid_y=True, 
                          group_tasks=True)

    # Jupyter Notebookで表示する場合
    pof.iplot(fig, filename='gantt-hours-minutes')

# %%
from gurobipy import*

def opt(jobs,qualifications):

    # x worker work 作業員をどの仕事に入れるか、0である場合もある
    # 仕事同士は被るかもしれない
    # y worker 作業員を取った変数を用意して、y worker=max(x worker for worker in workers)

    # job同士の被りチェック
    djob={}
    for i in range(len(jobs)):
        for j in range(len(jobs)):
            start1,end1=jobs[i]
            start2,end2=jobs[j]
            if end1<=start2 or end2<=start1:
                djob[(i,j)]=2
            else:
                djob[(i,j)]=1


    m=Model("shift")
#    m.setParam('OutputFlag',0)

    #作業員をどのjobに配置するか
    x={}

    #資格を持っていれば0か1のどちらか、なければ0
    for worker in qualifications:
        for work in range(len(jobs)):
            if work in qualifications[worker]:
                x[(worker,work)]=m.addVar(vtype="B",name=worker+"_作業"+str(work))
            else:
                x[(worker,work)]=m.addVar(vtype="I",ub=0,lb=0,name=worker+"_作業"+str(work))
    m.update()


    #その仕事に割り当てられるのは合計1である
    for work in range(len(jobs)):
        m.addConstr( quicksum(x[(worker,work)] for worker in qualifications)==1 )


    # 被った仕事に入れないという制約
    for worker in qualifications:
        for work1 in range(len(jobs)):
            for work2 in range(work1+1,len(jobs)):
                if djob[(work1,work2)]==1:
                    m.addConstr( x[(worker,work1)]+x[(worker,work2)] <= djob[(work1,work2)] )
        print("adding",worker,end=" ")

    # 作業員を取ったら1取らなかったら0という変数
    y={}
    for worker in qualifications:
        y[worker]=m.addVar(vtype="B", name=worker)


    for worker in qualifications:
        m.addConstr( y[worker]==or_( *[x[(worker,work)] for work in range(len(jobs))] ) )

    m.update()

    m.setObjective( quicksum( y[worker] for worker in qualifications ) ,GRB.MINIMIZE)

    #m.computeIIS()
    #m.write("model.ilp")   # 実行できないやつを探してくれる奴
    #m.write("model.lp")
    m.optimize()
    
    dworkerwork={}
    dworker=[]
    if m.Status == GRB.Status.OPTIMAL:
        for v in m.getVars():
            if v.X:
                ans=v.Varname.split("_")
                if len(ans)==2:

                    if ans[0] in dworkerwork:
                        print(ans[1],end=" ")
                        dworkerwork[ans[0]].append(ans[1])
                    else:
                        print("\n",ans[0],ans[1],end=" ")
                        dworkerwork[ans[0]]=[ans[1]]
                else:
                    dworker.append(ans[0])
        print ('最少人数',m.ObjVal)
    else:
        print("infeasible")
    #print(x)
    return dworkerwork,dworker

# %%
# クリーク？で制約
from gurobipy import*

def opt2(jobs,qualifications):

    # x worker work 作業員をどの仕事に入れるか、0である場合もある
    # 仕事同士は被るかもしれない
    # y worker 作業員を取った変数を用意して、y worker=max(x worker for worker in workers)

    #  クリーク列挙
    imos=[[]for i in range(max(max(j)for j in jobs)+1)]
    for i in range(len(jobs)):
        start,end=jobs[i]
        for j in range(start,end-1):
            imos[j].append(i)
    semicliques=[set(tp) for tp in set(map(tuple,[i for i in imos if i]))]
    cliques=[]
    for semiclique1 in semicliques:
        #ある一つのsemiqliqueが他のsemiqliqueの部分集合ならばそれはいらない
        if not sum( semiclique1<=semiclique2 for semiclique2 in semicliques if semiclique1!=semiclique2 ):
            cliques.append(semiclique1)
    djob={}
    for job in range(len(jobs)):
        for clique in cliques:
            if job in clique:
                if job in djob:
                    djob[job].append(clique)
                else:
                    djob[job]=[clique]


    m=Model("shift")
#    m.setParam('OutputFlag',0)
    m.params.MIPFocus = 3
    #作業員をどのjobに配置するか
    x={}

    #資格を持っていれば0か1のどちらか、なければ0
    for worker in qualifications:
        for work in range(len(jobs)):
            if work in qualifications[worker]:
                x[(worker,work)]=m.addVar(vtype="B",name=worker+"_作業"+str(work))
            else:
                x[(worker,work)]=m.addVar(vtype="I",ub=0,lb=0,name=worker+"_作業"+str(work))
    m.update()


    #その仕事に割り当てられるのは合計1である
    for work in range(len(jobs)):
        m.addConstr( quicksum(x[(worker,work)] for worker in qualifications)==1 )


    # 被った仕事に入れないという制約
    for worker in qualifications:
        for work in range(len(jobs)):
            if work in qualifications[worker]:
                if work in djob:
                    for clique in djob[work]:
                        m.addConstr( quicksum(x[(worker,job)] for job in clique) <= 1 )
        print("adding",worker,end=" ")

    # 作業員を取ったら1取らなかったら0という変数
    y={}
    for worker in qualifications:
        y[worker]=m.addVar(vtype="B", name=worker)


    for worker in qualifications:
        m.addConstr( y[worker]==or_( *[x[(worker,work)] for work in range(len(jobs))] ) )

    m.update()

    m.setObjective( quicksum( y[worker] for worker in qualifications ) ,GRB.MINIMIZE)

#    m.computeIIS()
#    m.write("model.ilp")   # 実行できないやつを探してくれる奴
#    m.write("model.lp")
    m.optimize()
    
    dworkerwork={}
    dworker=[]
    if m.Status == GRB.Status.OPTIMAL:
        for v in m.getVars():
            if v.X:
                ans=v.Varname.split("_")
                if len(ans)==2:

                    if ans[0] in dworkerwork:
                        print(ans[1],end=" ")
                        dworkerwork[ans[0]].append(ans[1])
                    else:
                        print("\n",ans[0],ans[1],end=" ")
                        dworkerwork[ans[0]]=[ans[1]]
                else:
                    dworker.append(ans[0])
        print ('最少人数',m.ObjVal)
    else:
        print("infeasible")
    #print(x)
    return dworkerwork,dworker

# %%
# networkxを使う
from gurobipy import*

def opt3(jobs,qualifications):
    G=nx.Graph()
    for i in range(len(jobs)):
        for j in range(i+1,len(jobs)):
            s1,e1=jobs[i]
            s2,e2=jobs[j]
            if not(e1<=s2 or e2<=s1):
                G.add_edge(i,j)
    cliques=tuple(map(set,nx.find_cliques(G)))
    
    m=Model("shift")
    try:
        m.params.MIPFocus = 3
    except:
        pass
    x,y={},{}
    
    for worker in qualifications:
        y[worker]=m.addVar(vtype="B",name=worker)
        for work in qualifications[worker]:
            x[(worker,work)]=m.addVar(vtype="B",name=worker+"_"+str(work))
    m.update()
    
    for work in range(len(jobs)):
        m.addConstr( quicksum( x[(worker,work)] for worker in qualifications if (worker,work) in x)==1 )
    
    for worker in qualifications:
        for clique in cliques:
            m.addConstr( quicksum( x[(worker,job)]for job in clique&qualifications[worker]  )<=y[worker] )

    m.setObjective(quicksum( y.values() ), GRB.MINIMIZE)
    m.optimize()
    
    dworkerwork={}
    dworker=[]
    if m.Status == GRB.Status.OPTIMAL:
        for v in m.getVars():
            if v.X:
                ans=v.Varname.split("_")
                if len(ans)==2:

                    if ans[0] in dworkerwork:
                        print(ans[1],end=" ")
                        dworkerwork[ans[0]].append(ans[1])
                    else:
                        print("\n",ans[0],ans[1],end=" ")
                        dworkerwork[ans[0]]=[ans[1]]
                else:
                    dworker.append(ans[0])
        print ('最少人数',m.ObjVal)
    else:
        print("infeasible")
    #print(x)
    return dworkerwork,dworker

# %%
import time
l=[]
for filename in glob.glob("./ptask/data_137_245_2105_33.dat"):
    start=time.time()
    _,filenumber,number_of_workers,number_of_jobs,multi_skilling_level=filename.replace(".dat","").split("_")
    filenumber,number_of_workers,number_of_jobs,multi_skilling_level=map(int,[filenumber,number_of_workers,number_of_jobs,multi_skilling_level])
    print(filenumber,number_of_workers,number_of_jobs,multi_skilling_level)
    
    file=open(filename).readlines()[5:]
    jobs=[tuple(map(int,line.split())) for line in file[:number_of_jobs]]
    qualifications=[tuple(map(int,line.replace(":","").split()))[1:] for line in file[number_of_jobs+1:]]
    qualifications={"作業員"+str(k):set(v) for k,v in enumerate(qualifications)} 

#    print(jobs)
#    print(qualifications)
    
#    dworkerwork,dworker=opt(jobs,qualifications)
#    dworkerwork,dworker=opt2(jobs,qualifications)
    dworkerwork,dworker=opt3(jobs,qualifications)

    drawrawwork(jobs)
    draw(jobs,dworkerwork)
    
    end=time.time()
    l.append(end-start)
#pd.DataFrame(l).to_excel("./a.xlsx")
# Out:
# 137 245 2105 33
# Changed value of parameter MIPFocus to 3
#    Prev: 0  Min: 0  Max: 3  Default: 0
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 199575 rows, 173360 columns and 11793100 nonzeros
# Model fingerprint: 0x91531459
# Variable types: 0 continuous, 173360 integer (173360 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 245.0000000
# Presolve removed 41110 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 60477 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 79782 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 98230 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 116519 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 120141 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 120141 rows and 0 columns (presolve time = 35s) ...
# Presolve removed 120141 rows and 0 columns (presolve time = 40s) ...
# Presolve removed 120141 rows and 0 columns (presolve time = 45s) ...
# Presolve removed 120141 rows and 0 columns
# Presolve time: 47.36s
# Presolved: 79434 rows, 173360 columns, 4797601 nonzeros
# Variable types: 0 continuous, 173360 integer (173360 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolved: 79434 rows, 173360 columns, 4797601 nonzeros
#
# Root barrier log...
#
# Ordering time: 3.32s
#
# Barrier statistics:
#  Dense cols : 245
#  AA' NZ     : 7.439e+06
#  Factor NZ  : 2.657e+07 (roughly 300 MBytes of memory)
#  Factor Ops : 1.407e+10 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.06405794e+02  1.41268899e+02  5.72e+01 7.87e-03  2.62e-02    57s
#    1   2.95568945e+02  2.54350715e+00  1.15e+01 1.11e-03  4.24e-03    57s
#    2   2.09034557e+02  2.89754720e+01  3.53e-14 4.64e-04  4.41e-04    58s
#    3   1.94599379e+02  1.44853395e+02  1.80e-14 5.17e-05  1.19e-04    58s
#    4   1.91853837e+02  1.54995848e+02  1.44e-14 4.08e-05  8.83e-05    59s
#    5   1.90690874e+02  1.72566385e+02  4.09e-14 8.67e-06  4.33e-05    59s
#    6   1.90541088e+02  1.89259362e+02  3.23e-13 3.88e-15  3.04e-06    60s
#    7   1.90000306e+02  1.89984662e+02  6.93e-13 2.80e-15  3.71e-08    60s
#    8   1.90000000e+02  1.90000000e+02  6.46e-12 3.66e-15  7.25e-14    61s
#
# Barrier solved model in 8 iterations and 60.58 seconds
# Optimal objective 1.90000000e+02
#
#
# Root crossover log...
#
#      153 DPushes remaining with DInf 0.0000000e+00                61s
#        0 DPushes remaining with DInf 0.0000000e+00                61s
#
#   170863 PPushes remaining with PInf 0.0000000e+00                61s
#   141325 PPushes remaining with PInf 0.0000000e+00                65s
#   133734 PPushes remaining with PInf 0.0000000e+00                70s
#   128710 PPushes remaining with PInf 0.0000000e+00                75s
#   124566 PPushes remaining with PInf 0.0000000e+00                80s
#   120907 PPushes remaining with PInf 0.0000000e+00                85s
#   117647 PPushes remaining with PInf 0.0000000e+00                90s
#   114753 PPushes remaining with PInf 0.0000000e+00                95s
#   111859 PPushes remaining with PInf 0.0000000e+00               100s
#   109333 PPushes remaining with PInf 0.0000000e+00               105s
#   106802 PPushes remaining with PInf 0.0000000e+00               110s
#   104467 PPushes remaining with PInf 0.0000000e+00               115s
#   102130 PPushes remaining with PInf 0.0000000e+00               120s
#    99989 PPushes remaining with PInf 0.0000000e+00               125s
#    97842 PPushes remaining with PInf 0.0000000e+00               130s
#    95704 PPushes remaining with PInf 0.0000000e+00               135s
#    93394 PPushes remaining with PInf 0.0000000e+00               140s
#    91430 PPushes remaining with PInf 0.0000000e+00               145s
#    89463 PPushes remaining with PInf 0.0000000e+00               150s
#    87327 PPushes remaining with PInf 0.0000000e+00               155s
#    85203 PPushes remaining with PInf 0.0000000e+00               160s
#    83243 PPushes remaining with PInf 0.0000000e+00               165s
#    81283 PPushes remaining with PInf 0.0000000e+00               170s
#    79315 PPushes remaining with PInf 0.0000000e+00               175s
#    77513 PPushes remaining with PInf 0.0000000e+00               180s
#    75708 PPushes remaining with PInf 0.0000000e+00               185s
#    73747 PPushes remaining with PInf 0.0000000e+00               190s
#    72109 PPushes remaining with PInf 0.0000000e+00               195s
#    70483 PPushes remaining with PInf 0.0000000e+00               200s
#    68854 PPushes remaining with PInf 0.0000000e+00               205s
#    67063 PPushes remaining with PInf 0.0000000e+00               210s
#    65446 PPushes remaining with PInf 0.0000000e+00               215s
#    63662 PPushes remaining with PInf 0.0000000e+00               221s
#    62203 PPushes remaining with PInf 0.0000000e+00               225s
#    60397 PPushes remaining with PInf 0.0000000e+00               230s
#    58699 PPushes remaining with PInf 0.0000000e+00               235s
#    57131 PPushes remaining with PInf 0.0000000e+00               240s
#    55508 PPushes remaining with PInf 0.0000000e+00               245s
#    53798 PPushes remaining with PInf 0.0000000e+00               250s
#    52235 PPushes remaining with PInf 0.0000000e+00               255s
#    50822 PPushes remaining with PInf 0.0000000e+00               260s
#    49343 PPushes remaining with PInf 0.0000000e+00               265s
#    48010 PPushes remaining with PInf 0.0000000e+00               270s
#    46668 PPushes remaining with PInf 0.0000000e+00               276s
#    45744 PPushes remaining with PInf 0.0000000e+00               281s
#    44796 PPushes remaining with PInf 0.0000000e+00               286s
#    43813 PPushes remaining with PInf 0.0000000e+00               291s
#    42558 PPushes remaining with PInf 0.0000000e+00               296s
#    41516 PPushes remaining with PInf 0.0000000e+00               300s
#    40183 PPushes remaining with PInf 0.0000000e+00               306s
#    39085 PPushes remaining with PInf 0.0000000e+00               311s
#    37728 PPushes remaining with PInf 0.0000000e+00               316s
#    36688 PPushes remaining with PInf 0.0000000e+00               320s
#    35274 PPushes remaining with PInf 0.0000000e+00               326s
#    34202 PPushes remaining with PInf 0.0000000e+00               331s
#    33093 PPushes remaining with PInf 0.0000000e+00               336s
#    31950 PPushes remaining with PInf 0.0000000e+00               341s
#    30744 PPushes remaining with PInf 0.0000000e+00               346s
#    29480 PPushes remaining with PInf 0.0000000e+00               351s
# Warning: 1 variables dropped from basis
#
# Restart crossover...
#
#   221959 variables added to crossover basis                      357s
#
#      153 DPushes remaining with DInf 0.0000000e+00               357s
#        0 DPushes remaining with DInf 0.0000000e+00               357s
#
#   170863 PPushes remaining with PInf 0.0000000e+00               357s
#   143530 PPushes remaining with PInf 0.0000000e+00               360s
#   134968 PPushes remaining with PInf 0.0000000e+00               365s
#   129100 PPushes remaining with PInf 0.0000000e+00               370s
#   124599 PPushes remaining with PInf 0.0000000e+00               375s
#   120767 PPushes remaining with PInf 0.0000000e+00               380s
#   117351 PPushes remaining with PInf 0.0000000e+00               385s
#   114277 PPushes remaining with PInf 0.0000000e+00               390s
#   111391 PPushes remaining with PInf 0.0000000e+00               395s
#   108685 PPushes remaining with PInf 0.0000000e+00               400s
#   106003 PPushes remaining with PInf 0.0000000e+00               405s
#   103333 PPushes remaining with PInf 0.0000000e+00               410s
#   100844 PPushes remaining with PInf 0.0000000e+00               415s
#    98373 PPushes remaining with PInf 0.0000000e+00               420s
#    96062 PPushes remaining with PInf 0.0000000e+00               425s
#    93758 PPushes remaining with PInf 0.0000000e+00               430s
#    91463 PPushes remaining with PInf 0.0000000e+00               435s
#    89333 PPushes remaining with PInf 0.0000000e+00               440s
#    87358 PPushes remaining with PInf 0.0000000e+00               445s
#    85234 PPushes remaining with PInf 0.0000000e+00               450s
#    83274 PPushes remaining with PInf 0.0000000e+00               455s
#    81314 PPushes remaining with PInf 0.0000000e+00               460s
#    79510 PPushes remaining with PInf 0.0000000e+00               465s
#    77545 PPushes remaining with PInf 0.0000000e+00               470s
#    75904 PPushes remaining with PInf 0.0000000e+00               475s
#    74105 PPushes remaining with PInf 0.0000000e+00               480s
#    72310 PPushes remaining with PInf 0.0000000e+00               485s
#    70518 PPushes remaining with PInf 0.0000000e+00               490s
#    68887 PPushes remaining with PInf 0.0000000e+00               495s
#    67260 PPushes remaining with PInf 0.0000000e+00               500s
#    65638 PPushes remaining with PInf 0.0000000e+00               505s
#    64007 PPushes remaining with PInf 0.0000000e+00               510s
#    62537 PPushes remaining with PInf 0.0000000e+00               515s
#    60907 PPushes remaining with PInf 0.0000000e+00               520s
#    59439 PPushes remaining with PInf 0.0000000e+00               525s
#    57972 PPushes remaining with PInf 0.0000000e+00               530s
#    56668 PPushes remaining with PInf 0.0000000e+00               535s
#    55358 PPushes remaining with PInf 0.0000000e+00               540s
#    53890 PPushes remaining with PInf 0.0000000e+00               546s
#    52748 PPushes remaining with PInf 0.0000000e+00               550s
#    51608 PPushes remaining with PInf 0.0000000e+00               555s
#    50464 PPushes remaining with PInf 0.0000000e+00               560s
#    49325 PPushes remaining with PInf 0.0000000e+00               565s
#    48347 PPushes remaining with PInf 0.0000000e+00               570s
#    47367 PPushes remaining with PInf 0.0000000e+00               575s
#    46225 PPushes remaining with PInf 0.0000000e+00               580s
#    45088 PPushes remaining with PInf 0.0000000e+00               585s
#    43949 PPushes remaining with PInf 0.0000000e+00               590s
#    42807 PPushes remaining with PInf 0.0000000e+00               595s
#    41506 PPushes remaining with PInf 0.0000000e+00               600s
#    40370 PPushes remaining with PInf 0.0000000e+00               606s
#    39389 PPushes remaining with PInf 0.0000000e+00               610s
#    38414 PPushes remaining with PInf 0.0000000e+00               615s
#    37278 PPushes remaining with PInf 0.0000000e+00               620s
#    36142 PPushes remaining with PInf 0.0000000e+00               625s
#    35004 PPushes remaining with PInf 0.0000000e+00               631s
#    34193 PPushes remaining with PInf 0.0000000e+00               636s
#    33211 PPushes remaining with PInf 0.0000000e+00               640s
#    32073 PPushes remaining with PInf 0.0000000e+00               646s
#    31092 PPushes remaining with PInf 0.0000000e+00               650s
#    30120 PPushes remaining with PInf 0.0000000e+00               655s
#    28982 PPushes remaining with PInf 0.0000000e+00               661s
#    28171 PPushes remaining with PInf 0.0000000e+00               665s
#    27361 PPushes remaining with PInf 0.0000000e+00               670s
#    26387 PPushes remaining with PInf 0.0000000e+00               676s
#    25575 PPushes remaining with PInf 0.0000000e+00               680s
#    24764 PPushes remaining with PInf 0.0000000e+00               685s
#    24113 PPushes remaining with PInf 0.0000000e+00               690s
#    23298 PPushes remaining with PInf 0.0000000e+00               695s
#    22324 PPushes remaining with PInf 0.0000000e+00               701s
#    21513 PPushes remaining with PInf 0.0000000e+00               705s
#    20534 PPushes remaining with PInf 0.0000000e+00               711s
#    19724 PPushes remaining with PInf 0.0000000e+00               715s
#    18751 PPushes remaining with PInf 0.0000000e+00               721s
#    17936 PPushes remaining with PInf 0.0000000e+00               726s
#    17126 PPushes remaining with PInf 0.0000000e+00               730s
#    16314 PPushes remaining with PInf 0.0000000e+00               735s
#    15501 PPushes remaining with PInf 0.0000000e+00               740s
#    14688 PPushes remaining with PInf 0.0000000e+00               745s
#    13876 PPushes remaining with PInf 0.0000000e+00               751s
#    13064 PPushes remaining with PInf 0.0000000e+00               756s
#    12247 PPushes remaining with PInf 0.0000000e+00               761s
#    11598 PPushes remaining with PInf 0.0000000e+00               765s
#    10787 PPushes remaining with PInf 0.0000000e+00               771s
#    10134 PPushes remaining with PInf 0.0000000e+00               776s
#     9648 PPushes remaining with PInf 0.0000000e+00               781s
#     9000 PPushes remaining with PInf 0.0000000e+00               786s
#     8350 PPushes remaining with PInf 0.0000000e+00               790s
#     7702 PPushes remaining with PInf 0.0000000e+00               795s
#     7054 PPushes remaining with PInf 0.0000000e+00               801s
#     6405 PPushes remaining with PInf 0.0000000e+00               806s
#     5757 PPushes remaining with PInf 0.0000000e+00               810s
#     5106 PPushes remaining with PInf 0.0000000e+00               815s
#     4294 PPushes remaining with PInf 0.0000000e+00               821s
#     3644 PPushes remaining with PInf 0.0000000e+00               826s
#     3157 PPushes remaining with PInf 0.0000000e+00               830s
#     2504 PPushes remaining with PInf 0.0000000e+00               836s
#     1850 PPushes remaining with PInf 0.0000000e+00               841s
#     1197 PPushes remaining with PInf 0.0000000e+00               845s
#      381 PPushes remaining with PInf 0.0000000e+00               851s
#        0 PPushes remaining with PInf 0.0000000e+00               854s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.9558248e-09    854s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   170947    1.9000000e+02   0.000000e+00   0.000000e+00    854s
#   170947    1.9000000e+02   0.000000e+00   0.000000e+00    855s
# Concurrent spin time: 254.76s (can be avoided by choosing Method=3)
#
# Solved with barrier
#
# Root relaxation: objective 1.900000e+02, 170947 iterations, 1061.78 seconds
# Total elapsed time = 1279.45s
